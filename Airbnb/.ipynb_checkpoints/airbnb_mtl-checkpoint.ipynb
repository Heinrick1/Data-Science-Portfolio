# %%
#data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 1. Problem Definition
#
# We will try to predict as accurately as possible the rating of airbnb rental places based on the set of features available from the airbnb website.

# %% [markdown]
# # 2. Acquiring data

# %%
df = pd.read_csv('airbnb_mtl_2017.csv')
df.head()
# Out:
#     room_id  survey_id    host_id    room_type  country      city  borough  \
# 0  15023220       1556   90096724  Shared room      NaN  Montreal      NaN
# 1   1132103       1556    4162573  Shared room      NaN  Montreal      NaN
# 2  16852877       1556  112242374  Shared room      NaN  Montreal      NaN
# 3  15868419       1556   37807481  Shared room      NaN  Montreal      NaN
# 4   7067433       1556   36987539  Shared room      NaN  Montreal      NaN
#
#                           neighborhood  reviews  overall_satisfaction  \
# 0            Rosemont-La Petite-Patrie        4                   5.0
# 1                          Ville-Marie       20                   5.0
# 2                          Ville-Marie        0                   0.0
# 3  Côte-des-Neiges-Notre-Dame-de-Grâce        0                   0.0
# 4                               Verdun        5                   5.0
#
#    accommodates  bedrooms  bathrooms  price  minstay  \
# 0             1       1.0        NaN   52.0      NaN
# 1             1       1.0        NaN   53.0      NaN
# 2             1       1.0        NaN   22.0      NaN
# 3             2       1.0        NaN   11.0      NaN
# 4             2       1.0        NaN   14.0      NaN
#
#                 last_modified   latitude  longitude  \
# 0  2017-08-10 12:16:04.309376  45.544091 -73.594396
# 1  2017-08-10 12:16:04.306407  45.506773 -73.568754
# 2  2017-08-10 12:16:03.221824  45.499342 -73.561761
# 3  2017-08-10 12:16:03.216672  45.497517 -73.620404
# 4  2017-08-10 12:16:01.807632  45.458891 -73.571854
#
#                                             location
# 0  0101000020E6100000E33785950A6652C023861DC6A4C5...
# 1  0101000020E6100000075E2D77666452C077BF0AF0DDC0...
# 2  0101000020E6100000C5CA68E4F36352C076C24B70EABF...
# 3  0101000020E6100000AF93FAB2B46752C01E1A16A3AEBF...
# 4  0101000020E61000008E058541996452C0E1B6B6F0BCBA...

# %% [markdown]
# # 3. Exploratory analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15871 entries, 0 to 15870
# Data columns (total 19 columns):
# room_id                 15871 non-null int64
# survey_id               15871 non-null int64
# host_id                 15871 non-null int64
# room_type               15871 non-null object
# country                 0 non-null float64
# city                    15871 non-null object
# borough                 0 non-null float64
# neighborhood            15871 non-null object
# reviews                 15871 non-null int64
# overall_satisfaction    15871 non-null float64
# accommodates            15871 non-null int64
# bedrooms                15871 non-null float64
# bathrooms               0 non-null float64
# price                   15871 non-null float64
# minstay                 0 non-null float64
# last_modified           15871 non-null object
# latitude                15871 non-null float64
# longitude               15871 non-null float64
# location                15871 non-null object
# dtypes: float64(9), int64(5), object(5)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#             room_id  survey_id       host_id  country  borough       reviews  \
# count  1.587100e+04    15871.0  1.587100e+04      0.0      0.0  15871.000000
# mean   1.267598e+07     1556.0  4.249606e+07      NaN      NaN     13.708147
# std    6.037289e+06        0.0  4.099071e+07      NaN      NaN     27.262039
# min    2.078000e+03     1556.0  2.277000e+03      NaN      NaN      0.000000
# 25%    7.455968e+06     1556.0  9.029670e+06      NaN      NaN      1.000000
# 50%    1.385953e+07     1556.0  2.846512e+07      NaN      NaN      4.000000
# 75%    1.834907e+07     1556.0  6.605928e+07      NaN      NaN     13.000000
# max    2.036531e+07     1556.0  1.452571e+08      NaN      NaN    384.000000
#
#        overall_satisfaction  accommodates      bedrooms  bathrooms  \
# count          15871.000000  15871.000000  15871.000000        0.0
# mean               2.733571      3.440174      1.386995        NaN
# std                2.337014      2.236279      0.954777        NaN
# min                0.000000      1.000000      0.000000        NaN
# 25%                0.000000      2.000000      1.000000        NaN
# 50%                4.500000      3.000000      1.000000        NaN
# 75%                5.000000      4.000000      2.000000        NaN
# max                5.000000     16.000000     13.000000        NaN
#
#               price  minstay      latitude     longitude
# count  15871.000000      0.0  15871.000000  15871.000000
# mean      81.201185      NaN     45.516441    -73.587557
# std      128.253164      NaN      0.027877      0.037085
# min        8.000000      NaN     45.403320    -73.955358
# 25%       38.000000      NaN     45.500110    -73.601622
# 50%       61.000000      NaN     45.519621    -73.579494
# 75%       96.500000      NaN     45.533413    -73.567261
# max     8114.000000      NaN     45.698305    -73.481893

# %%
df.describe(include=['O'])
# Out:
#               room_type      city           neighborhood  \
# count             15871     15871                  15871
# unique                3         1                     32
# top     Entire home/apt  Montreal  Le Plateau-Mont-Royal
# freq              10794     15871                   4736
#
#                      last_modified  \
# count                        15871
# unique                       15871
# top     2017-08-10 03:39:09.701193
# freq                             1
#
#                                                  location
# count                                               15871
# unique                                              15870
# top     0101000020E6100000423EE8D9AC6452C08D429259BDC1...
# freq                                                    2

# %%
df.room_type.value_counts()
# Out:
# Entire home/apt    10794
# Private room        4932
# Shared room          145
# Name: room_type, dtype: int64

# %% [markdown]
# We can already determine that:
# * country, borough, bathrooms and minstay are empty columns that we will delete (1)
# * **room_id**, **location** and **host_id** are unique identifying features
# * **survey_id** is always 1556.0, **city** is always montreal we will discard them as well (2)
#
# We are not treating this data as a time series, we will therefore **drop last-modified** (3)
#
# We have X numerical variables
# * continuous: Price, overall satisfaction
# * discrete: host_id, accomodates, reviews
#
# We have Y categorical variables:
# * room_type with 3 categories: "Entire home/apt", "Shared room", "Private room"
# * neighborhood: 32 of the different neighborhoods in montreal
#
# We will want to rework the geographic information to make it a value we can use with machine learning

# %% [markdown]
# ### Looking at the review (target) variable

# %%
df['overall_satisfaction'].describe()
# Out:
# count    15871.000000
# mean         2.733571
# std          2.337014
# min          0.000000
# 25%          0.000000
# 50%          4.500000
# 75%          5.000000
# max          5.000000
# Name: overall_satisfaction, dtype: float64

# %%
#histogram
sns.distplot(df['overall_satisfaction']);

# %% [markdown]
# It is important to note that most of the 0 reviews come from listings that were not rated, therefore we will drop all the listing that were not rated from the sample (4)

# %%
df.overall_satisfaction.value_counts()
# Out:
# 0.0    6643
# 5.0    4846
# 4.5    3517
# 4.0     676
# 3.5     138
# 3.0      31
# 2.5      16
# 2.0       4
# Name: overall_satisfaction, dtype: int64

# %% [markdown]
# It is however intriguing that so many of the ratings are above 3 and virtually none them is between 1 and 3. After further research and comparing with other airbnb datasets, in turns out it is a recurrent problem in airbnb ratings, a disproportionate amount of the ratings is above 4.5, it could be interesting to look at how ratings are computed and further inquire that review system that seems fairly flawed. For now we will try to see if we can obtain a good accuracy in predicting them anyways.

# %%
df.host_id.value_counts().head()
# Out:
# 12243051    153
# 778430       50
# 38459934     48
# 318040       36
# 15935760     29
# Name: host_id, dtype: int64

# %% [markdown]
# some host have several postings, we could create a new feature linking of the number of postings of the owner to each room, to see if the experience of a host correlates with the quality of the rankings

# %% [markdown]
# # 4. Feature engineering and modification

# %%
#dropping the dicussed columns
df = df.drop(["country","survey_id","last_modified","city","borough","bathrooms","minstay"], axis=1)

# %%
df.reviews.value_counts()
# Out:
# 0      3535
# 1      1790
# 2      1313
# 3       976
# 4       837
# 5       648
# 6       578
# 7       457
# 8       374
# 9       333
# 10      314
# 11      307
# 12      256
# 13      210
# 14      203
# 16      190
# 15      177
# 17      163
# 18      138
# 20      123
# 19      122
# 21      105
# 22      104
# 24       81
# 28       81
# 23       80
# 27       78
# 25       77
# 30       73
# 26       72
#        ...
# 206       1
# 230       1
# 270       1
# 294       1
# 207       1
# 215       1
# 231       1
# 255       1
# 292       1
# 268       1
# 193       1
# 228       1
# 201       1
# 273       1
# 281       1
# 162       1
# 170       1
# 210       1
# 258       1
# 266       1
# 330       1
# 155       1
# 203       1
# 219       1
# 243       1
# 295       1
# 140       1
# 164       1
# 220       1
# 267       1
# Name: reviews, Length: 223, dtype: int64

# %%
#Dropping 0 columns
df = df[df.reviews != 0]

sns.distplot(df['overall_satisfaction']);

# %%
revs = df.reviews.value_counts()
df[df["overall_satisfaction"]  == 0]
# Out:
#         room_id    host_id        room_type  \
# 5      13274638   20707779      Shared room
# 6      12851518   70209623      Shared room
# 7       9575322     567555      Shared room
# 9      17993466  109574051      Shared room
# 11     18477982  109574051      Shared room
# 14     18462865  109574051      Shared room
# 24      9371397   48623424      Shared room
# 25     15635848     909296      Shared room
# 40     19605547  128394836      Shared room
# 42     19718263  121785123      Shared room
# 46     15812199   82410876      Shared room
# 47     14143064   12848069      Shared room
# 60     14968868   94276942      Shared room
# 62     11361101   59515508      Shared room
# 65     20230928   46488200      Shared room
# 71     19945877    7881297      Shared room
# 73     11421258   59986180      Shared room
# 79     20126412  138846933      Shared room
# 81     11893693   19059347      Shared room
# 83     19153043  133912862      Shared room
# 88     15398085   88484249      Shared room
# 96      7956781     455835      Shared room
# 97     16612938  109646890      Shared room
# 100    19096240   41270538      Shared room
# 103    19769492   72008548      Shared room
# 114    20188246  138846933      Shared room
# 138    11322880   59227416  Entire home/apt
# 145      317740    1630921  Entire home/apt
# 147     4494120   17980675  Entire home/apt
# 150     5839427   30317665  Entire home/apt
# ...         ...        ...              ...
# 15680   6138575    7532148     Private room
# 15683  18945249  132078355     Private room
# 15685  10414692   39762400     Private room
# 15686  10704559   55311357     Private room
# 15691  16725901   26364481     Private room
# 15694  18950277  132125795     Private room
# 15695  19661755   13833880     Private room
# 15701  14237038   32279578     Private room
# 15703   7856601   28872785     Private room
# 15712  18178750   63797452     Private room
# 15716  16825147   40794085     Private room
# 15717  18527327   84448084     Private room
# 15723  18849404   32223209     Private room
# 15735   5343238    3405939     Private room
# 15744  19569264   17892679     Private room
# 15757  18198748  116898362     Private room
# 15760   5070752   26186633     Private room
# 15767  19954950  140150820     Private room
# 15772  19617564   27539676     Private room
# 15779  19951131    3625279     Private room
# 15784  20282586  138342315     Private room
# 15785  19327710  135382966     Private room
# 15802  14295186   17199903     Private room
# 15822  20150077   65904968     Private room
# 15827  19228366   16562261     Private room
# 15829  19888221   10071856     Private room
# 15835  19802584  139864737     Private room
# 15839  18656001  129644114     Private room
# 15844  19607222  137865603     Private room
# 15859  19644194  138268625     Private room
#
#                                neighborhood  reviews  overall_satisfaction  \
# 5                 Rosemont-La Petite-Patrie        2                   0.0
# 6                 Rosemont-La Petite-Patrie        1                   0.0
# 7                               Ville-Marie        1                   0.0
# 9                               Ville-Marie        2                   0.0
# 11                              Ville-Marie        2                   0.0
# 14                              Ville-Marie        1                   0.0
# 24                                   Dorval        2                   0.0
# 25                    Le Plateau-Mont-Royal        1                   0.0
# 40                              Ville-Marie        2                   0.0
# 42                              Ville-Marie        1                   0.0
# 46                              Ville-Marie        2                   0.0
# 47                    Le Plateau-Mont-Royal        1                   0.0
# 60                    Le Plateau-Mont-Royal        1                   0.0
# 62                Rosemont-La Petite-Patrie        2                   0.0
# 65                    Le Plateau-Mont-Royal        1                   0.0
# 71                    Le Plateau-Mont-Royal        1                   0.0
# 73     Villeray-Saint-Michel-Parc-Extension        1                   0.0
# 79                              Ville-Marie        1                   0.0
# 81      Côte-des-Neiges-Notre-Dame-de-Grâce        1                   0.0
# 83                    Le Plateau-Mont-Royal        1                   0.0
# 88                            Montréal-Nord        2                   0.0
# 96                Rosemont-La Petite-Patrie        2                   0.0
# 97                             Le Sud-Ouest        1                   0.0
# 100                   Le Plateau-Mont-Royal        2                   0.0
# 103    Villeray-Saint-Michel-Parc-Extension        1                   0.0
# 114                             Ville-Marie        2                   0.0
# 138                   Le Plateau-Mont-Royal        2                   0.0
# 145                   Le Plateau-Mont-Royal        2                   0.0
# 147                   Le Plateau-Mont-Royal        1                   0.0
# 150                             Baie-d'Urfé        2                   0.0
# ...                                     ...      ...                   ...
# 15680             Rosemont-La Petite-Patrie        2                   0.0
# 15683                                 Anjou        1                   0.0
# 15685                                 Anjou        2                   0.0
# 15686         Mercier-Hochelaga-Maisonneuve        1                   0.0
# 15691         Mercier-Hochelaga-Maisonneuve        1                   0.0
# 15694                         Saint-Léonard        2                   0.0
# 15695                         Saint-Léonard        1                   0.0
# 15701                                 Anjou        2                   0.0
# 15703         Mercier-Hochelaga-Maisonneuve        2                   0.0
# 15712         Mercier-Hochelaga-Maisonneuve        2                   0.0
# 15716             Rosemont-La Petite-Patrie        1                   0.0
# 15717                           Ville-Marie        1                   0.0
# 15723                 Le Plateau-Mont-Royal        2                   0.0
# 15735                           Ville-Marie        1                   0.0
# 15744                 Le Plateau-Mont-Royal        2                   0.0
# 15757             Rosemont-La Petite-Patrie        1                   0.0
# 15760         Mercier-Hochelaga-Maisonneuve        2                   0.0
# 15767             Rosemont-La Petite-Patrie        1                   0.0
# 15772                 Ahuntsic-Cartierville        1                   0.0
# 15779         Mercier-Hochelaga-Maisonneuve        2                   0.0
# 15784                         Saint-Léonard        1                   0.0
# 15785         Mercier-Hochelaga-Maisonneuve        1                   0.0
# 15802                 Le Plateau-Mont-Royal        1                   0.0
# 15822                           Ville-Marie        1                   0.0
# 15827                 Le Plateau-Mont-Royal        2                   0.0
# 15829                           Ville-Marie        1                   0.0
# 15835             Rosemont-La Petite-Patrie        1                   0.0
# 15839                 Ahuntsic-Cartierville        1                   0.0
# 15844                           Ville-Marie        2                   0.0
# 15859   Côte-des-Neiges-Notre-Dame-de-Grâce        1                   0.0
#
#        accommodates  bedrooms  price   latitude  longitude  \
# 5                 2       1.0   20.0  45.547610 -73.574754
# 6                 1       1.0   12.0  45.551003 -73.575831
# 7                 1       1.0   30.0  45.527419 -73.550308
# 9                 1       1.0   25.0  45.493142 -73.581011
# 11                1       1.0   33.0  45.491874 -73.581281
# 14                1       1.0   25.0  45.491844 -73.581337
# 24                1       1.0   33.0  45.454609 -73.775332
# 25                2       1.0   29.0  45.537123 -73.585289
# 40                1       1.0   18.0  45.529317 -73.546652
# 42                1       1.0   25.0  45.492829 -73.581142
# 46                1       1.0   24.0  45.496054 -73.590979
# 47                1       1.0   21.0  45.520780 -73.596176
# 60                1       1.0   29.0  45.508605 -73.573817
# 62                1       1.0   27.0  45.542244 -73.597151
# 65                1       1.0   29.0  45.512819 -73.575434
# 71                2       1.0   21.0  45.538722 -73.574839
# 73                2       1.0   13.0  45.527646 -73.620814
# 79                2       1.0   25.0  45.493106 -73.583026
# 81                3       1.0   33.0  45.483307 -73.620890
# 83                1       1.0   29.0  45.521955 -73.566317
# 88                1       1.0   25.0  45.583731 -73.631088
# 96                1       1.0   18.0  45.538269 -73.596258
# 97                1       1.0   21.0  45.448200 -73.593915
# 100               2       1.0   31.0  45.525862 -73.574857
# 103               1       1.0   12.0  45.542612 -73.625354
# 114               2       1.0   25.0  45.493588 -73.582511
# 138               6       2.0   77.0  45.526034 -73.585067
# 145               6       3.0  102.0  45.532728 -73.571356
# 147               8       4.0  770.0  45.526160 -73.580943
# 150               8       4.0  489.0  45.418105 -73.903370
# ...             ...       ...    ...        ...        ...
# 15680             1       1.0   31.0  45.571321 -73.574618
# 15683             2       1.0   25.0  45.605401 -73.583035
# 15685             2       1.0   21.0  45.608193 -73.545517
# 15686             2       1.0   21.0  45.576573 -73.543134
# 15691             1       1.0   21.0  45.576481 -73.555400
# 15694             2       1.0   23.0  45.570479 -73.583556
# 15695             2       3.0   31.0  45.598388 -73.612224
# 15701            16       1.0   29.0  45.609580 -73.545390
# 15703             2       1.0   32.0  45.591633 -73.547907
# 15712             1       1.0   16.0  45.595649 -73.513311
# 15716             2       1.0   12.0  45.536637 -73.604793
# 15717             2       1.0   29.0  45.518264 -73.559514
# 15723             2       1.0   18.0  45.521747 -73.573099
# 15735             2       1.0   29.0  45.529152 -73.562067
# 15744             1       1.0   25.0  45.524806 -73.608068
# 15757             2       1.0   33.0  45.552602 -73.565696
# 15760             1       1.0   37.0  45.554631 -73.546266
# 15767             2       1.0   24.0  45.556302 -73.591845
# 15772             4       2.0   27.0  45.542962 -73.670572
# 15779             2       1.0   40.0  45.592415 -73.530258
# 15784             1       1.0   15.0  45.597916 -73.593330
# 15785             2       1.0   20.0  45.593384 -73.562297
# 15802             2       1.0   22.0  45.533591 -73.568997
# 15822             2       1.0   22.0  45.524505 -73.564103
# 15827             2       1.0   25.0  45.521884 -73.571989
# 15829             2       1.0   40.0  45.516464 -73.559939
# 15835             2       1.0   22.0  45.539925 -73.611611
# 15839             3       1.0   26.0  45.543093 -73.644462
# 15844             2       1.0   27.0  45.516241 -73.558694
# 15859             2       1.0   22.0  45.472651 -73.613342
#
#                                                 location
# 5      0101000020E6100000B14F00C5C86452C0357BA01518C6...
# 6      0101000020E61000007841446ADA6452C0BB7F2C4487C6...
# 7      0101000020E61000008AAE0B3F386352C0FF243E7782C3...
# 9      0101000020E610000071E7C2482F6552C05B24ED461FBF...
# 11     0101000020E6100000513239B5336552C059E02BBAF5BE...
# 14     0101000020E61000001BBD1AA0346552C0EE5D83BEF4BE...
# 24     0101000020E6100000B5E21B0A9F7152C0CFBBB1A030BA...
# 25     0101000020E6100000596DFE5F756552C0F7764B72C0C4...
# 40     0101000020E6100000C092AB58FC6252C0C11BD2A8C0C3...
# 42     0101000020E61000004015376E316552C09CC24A0515BF...
# 46     0101000020E6100000DC679599D26552C066868DB27EBF...
# 47     0101000020E61000003FAA61BF276652C0983446EBA8C2...
# 60     0101000020E6100000E338F06AB96452C082CAF8F719C1...
# 62     0101000020E610000084F1D3B8376652C0E2395B4068C5...
# 65     0101000020E61000006AC020E9D36452C03BE2900DA4C1...
# 71     0101000020E6100000C85D8429CA6452C05FD1ADD7F4C4...
# 73     0101000020E610000088B9A46ABB6752C0BFEE74E789C3...
# 79     0101000020E6100000EFAD484C506552C00EBBEF181EBF...
# 81     0101000020E6100000761A69A9BC6752C0C576F700DDBD...
# 83     0101000020E6100000CE8AA8893E6452C0E97DE36BCFC2...
# 88     0101000020E61000007A39ECBE636852C0A85489B2B7CA...
# 96     0101000020E61000009E7E5017296652C0AEB9A3FFE5C4...
# 97     0101000020E6100000A5660FB4026652C09A081B9E5EB9...
# 100    0101000020E61000001BB80375CA6452C0C51A2E724FC3...
# 103    0101000020E61000000F9BC8CC056852C065355D4F74C5...
# 114    0101000020E6100000DBA337DC476552C05AD93EE42DBF...
# 138    0101000020E610000001BEDBBC716552C0C34A051555C3...
# 145    0101000020E6100000E597C118916452C0EDD45C6E30C4...
# 147    0101000020E6100000C5758C2B2E6552C04F3BFC3559C3...
# 150    0101000020E6100000008C67D0D07952C0A4A5F27684B5...
# ...                                                  ...
# 15680  0101000020E6100000596C938AC66452C04E42E90B21C9...
# 15683  0101000020E6100000185B0872506552C09CFBABC77DCD...
# 15685  0101000020E61000005F9A22C0E96252C0FC53AA44D9CD...
# 15686  0101000020E61000001FD61BB5C26252C0D960E124CDC9...
# 15691  0101000020E6100000B30C71AC8B6352C0F8E12021CAC9...
# 15694  0101000020E61000009DD843FB586552C00307B47405C9...
# 15695  0101000020E6100000E27492AD2E6752C0D0285DFA97CC...
# 15701  0101000020E6100000306475ABE76252C0D925AAB706CE...
# 15703  0101000020E6100000F78F85E8106352C0001E51A1BACB...
# 15712  0101000020E6100000556B6116DA6052C09372F7393ECC...
# 15716  0101000020E610000062F6B2EDB46652C06A696E85B0C4...
# 15717  0101000020E6100000DDE9CE13CF6352C0DA58897956C2...
# 15723  0101000020E6100000B3976DA7AD6452C09FE40E9BC8C2...
# 15735  0101000020E61000004BCADDE7F86352C0774EB340BBC3...
# 15744  0101000020E6100000A06F0B96EA6652C04E5FCFD72CC3...
# 15757  0101000020E610000098DEFE5C346452C023DA8EA9BBC6...
# 15760  0101000020E6100000AC3AAB05F66252C0842C0B26FEC6...
# 15767  0101000020E610000046D3D9C9E06552C0865968E734C7...
# 15772  0101000020E61000004167D2A6EA6A52C0427C60C77FC5...
# 15779  0101000020E6100000501C40BFEF6152C076543541D4CB...
# 15784  0101000020E6100000156F641EF96552C0A8E0F08288CC...
# 15785  0101000020E6100000E4688EACFC6352C01EFCC401F4CB...
# 15802  0101000020E61000006AA164726A6452C05038BBB54CC4...
# 15822  0101000020E6100000D52478431A6452C053CBD6FA22C3...
# 15827  0101000020E6100000FE2AC0779B6452C020274C18CDC2...
# 15829  0101000020E61000005130630AD66352C0DAC70A7E1BC2...
# 15835  0101000020E6100000EDB776A2246752C07AA52C431CC5...
# 15839  0101000020E6100000F2608BDD3E6952C0E0D7481284C5...
# 15844  0101000020E61000002C9E7AA4C16352C05BED612F14C2...
# 15859  0101000020E6100000D9D0CDFE406752C0FAB5F5D37FBC...
#
# [3108 rows x 12 columns]

# %% [markdown]
# There is still a significant number of 0 ratings. Part of the reason is the fact that people who review do not HAVE to leave a ratings, they CAN leave a rating in addition to their review. That adds an interesting component to our prediction since most of those 0 ratings are due to the fact that people did not rate the appartment. We could either discard them assuming that is the case, or keep the ratings, technically we are still solving the same question of "What will the rating" be, however there is a new dimension to it: "Will there be a rating ?" We unfortunately cannot clearly separate both here without making some really strong assumptions so we will see how our predictive models perform with the 0 ratings in the set.

# %%
df.head()
# Out:
#     room_id   host_id    room_type               neighborhood  reviews  \
# 0  15023220  90096724  Shared room  Rosemont-La Petite-Patrie        4
# 1   1132103   4162573  Shared room                Ville-Marie       20
# 4   7067433  36987539  Shared room                     Verdun        5
# 5  13274638  20707779  Shared room  Rosemont-La Petite-Patrie        2
# 6  12851518  70209623  Shared room  Rosemont-La Petite-Patrie        1
#
#    overall_satisfaction  accommodates  bedrooms  price   latitude  longitude  \
# 0                   5.0             1       1.0   52.0  45.544091 -73.594396
# 1                   5.0             1       1.0   53.0  45.506773 -73.568754
# 4                   5.0             2       1.0   14.0  45.458891 -73.571854
# 5                   0.0             2       1.0   20.0  45.547610 -73.574754
# 6                   0.0             1       1.0   12.0  45.551003 -73.575831
#
#                                             location
# 0  0101000020E6100000E33785950A6652C023861DC6A4C5...
# 1  0101000020E6100000075E2D77666452C077BF0AF0DDC0...
# 4  0101000020E61000008E058541996452C0E1B6B6F0BCBA...
# 5  0101000020E6100000B14F00C5C86452C0357BA01518C6...
# 6  0101000020E61000007841446ADA6452C0BB7F2C4487C6...

# %% [markdown]
# We now need to encode the categorical variables for neighborhood and room_type. Since none of these is ordinal, we will use one hot encoding. (5)

# %% [markdown]
# In this first attempt, we will use latitude and longitude to calculate the distance between each place and the heart of downtown montreal, that we will arbitrarily define as the middle of the postal code polygon corresponding to it, situated approximately at 45.505369, -73.566107.
#
# Let us now add a column corresponding to that distance  for each record, using the geopy plugin to compute the distance between two points

# %%
from geopy.distance import vincenty
#downtown_mtl = (45.505369, -73.566107)
#cleveland_oh = (41.499498, -81.695391)
#print(vincenty(downtown_mtl, cleveland_oh).miles)

#the vincenty function uses the vincenty formula to compute the distance between two points defined by their
#latitude and longitude
df['downtown_dist'] = df.apply (lambda row: vincenty((row['latitude'], row['longitude']), downtown_mtl).kilometers,axis=1)

# %%
df.head()
# Out:
#     room_id   host_id    room_type               neighborhood  reviews  \
# 0  15023220  90096724  Shared room  Rosemont-La Petite-Patrie        4
# 1   1132103   4162573  Shared room                Ville-Marie       20
# 4   7067433  36987539  Shared room                     Verdun        5
# 5  13274638  20707779  Shared room  Rosemont-La Petite-Patrie        2
# 6  12851518  70209623  Shared room  Rosemont-La Petite-Patrie        1
#
#    overall_satisfaction  accommodates  bedrooms  price   latitude  longitude  \
# 0                   5.0             1       1.0   52.0  45.544091 -73.594396
# 1                   5.0             1       1.0   53.0  45.506773 -73.568754
# 4                   5.0             2       1.0   14.0  45.458891 -73.571854
# 5                   0.0             2       1.0   20.0  45.547610 -73.574754
# 6                   0.0             1       1.0   12.0  45.551003 -73.575831
#
#                                             location  downtown_dist
# 0  0101000020E6100000E33785950A6652C023861DC6A4C5...       4.837937
# 1  0101000020E6100000075E2D77666452C077BF0AF0DDC0...       0.259116
# 4  0101000020E61000008E058541996452C0E1B6B6F0BCBA...       5.185125
# 5  0101000020E6100000B14F00C5C86452C0357BA01518C6...       4.743102
# 6  0101000020E61000007841446ADA6452C0BB7F2C4487C6...       5.128429

# %% [markdown]
# We will for now get rid of the latitude longitude and location string.

# %%
df.drop(["latitude", "longitude", "location"], axis = 1, inplace=True)
df.head()
# Out:
#     room_id   host_id    room_type               neighborhood  reviews  \
# 0  15023220  90096724  Shared room  Rosemont-La Petite-Patrie        4
# 1   1132103   4162573  Shared room                Ville-Marie       20
# 4   7067433  36987539  Shared room                     Verdun        5
# 5  13274638  20707779  Shared room  Rosemont-La Petite-Patrie        2
# 6  12851518  70209623  Shared room  Rosemont-La Petite-Patrie        1
#
#    overall_satisfaction  accommodates  bedrooms  price  downtown_dist
# 0                   5.0             1       1.0   52.0       4.837937
# 1                   5.0             1       1.0   53.0       0.259116
# 4                   5.0             2       1.0   14.0       5.185125
# 5                   0.0             2       1.0   20.0       4.743102
# 6                   0.0             1       1.0   12.0       5.128429

# %% [markdown]
# Let us now perform one hot encoding using the pandas get dummies functions

# %%
df_ohe= pd.get_dummies(df)

# %%
df_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12336 entries, 0 to 15870
# Data columns (total 43 columns):
# room_id                                                  12336 non-null int64
# host_id                                                  12336 non-null int64
# reviews                                                  12336 non-null int64
# overall_satisfaction                                     12336 non-null float64
# accommodates                                             12336 non-null int64
# bedrooms                                                 12336 non-null float64
# price                                                    12336 non-null float64
# downtown_dist                                            12336 non-null float64
# room_type_Entire home/apt                                12336 non-null uint8
# room_type_Private room                                   12336 non-null uint8
# room_type_Shared room                                    12336 non-null uint8
# neighborhood_Ahuntsic-Cartierville                       12336 non-null uint8
# neighborhood_Anjou                                       12336 non-null uint8
# neighborhood_Baie-d'Urfé                                 12336 non-null uint8
# neighborhood_Beaconsfield                                12336 non-null uint8
# neighborhood_Côte-Saint-Luc                              12336 non-null uint8
# neighborhood_Côte-des-Neiges-Notre-Dame-de-Grâce         12336 non-null uint8
# neighborhood_Dollard-des-Ormeaux                         12336 non-null uint8
# neighborhood_Dorval                                      12336 non-null uint8
# neighborhood_Hampstead                                   12336 non-null uint8
# neighborhood_Kirkland                                    12336 non-null uint8
# neighborhood_L'Île-Bizard-Sainte-Geneviève               12336 non-null uint8
# neighborhood_LaSalle                                     12336 non-null uint8
# neighborhood_Lachine                                     12336 non-null uint8
# neighborhood_Le Plateau-Mont-Royal                       12336 non-null uint8
# neighborhood_Le Sud-Ouest                                12336 non-null uint8
# neighborhood_Mercier-Hochelaga-Maisonneuve               12336 non-null uint8
# neighborhood_Mont-Royal                                  12336 non-null uint8
# neighborhood_Montréal-Est                                12336 non-null uint8
# neighborhood_Montréal-Nord                               12336 non-null uint8
# neighborhood_Montréal-Ouest                              12336 non-null uint8
# neighborhood_Outremont                                   12336 non-null uint8
# neighborhood_Pierrefonds-Roxboro                         12336 non-null uint8
# neighborhood_Pointe-Claire                               12336 non-null uint8
# neighborhood_Rivière-des-Prairies-Pointe-aux-Trembles    12336 non-null uint8
# neighborhood_Rosemont-La Petite-Patrie                   12336 non-null uint8
# neighborhood_Saint-Laurent                               12336 non-null uint8
# neighborhood_Saint-Léonard                               12336 non-null uint8
# neighborhood_Sainte-Anne-de-Bellevue                     12336 non-null uint8
# neighborhood_Verdun                                      12336 non-null uint8
# neighborhood_Ville-Marie                                 12336 non-null uint8
# neighborhood_Villeray-Saint-Michel-Parc-Extension        12336 non-null uint8
# neighborhood_Westmount                                   12336 non-null uint8
# dtypes: float64(4), int64(4), uint8(35)
# memory usage: 1.6 MB

# %%
df_ohe.head()
# Out:
#     room_id   host_id  reviews  overall_satisfaction  accommodates  bedrooms  \
# 0  15023220  90096724        4                   5.0             1       1.0
# 1   1132103   4162573       20                   5.0             1       1.0
# 4   7067433  36987539        5                   5.0             2       1.0
# 5  13274638  20707779        2                   0.0             2       1.0
# 6  12851518  70209623        1                   0.0             1       1.0
#
#    price  downtown_dist  room_type_Entire home/apt  room_type_Private room  \
# 0   52.0       4.837937                          0                       0
# 1   53.0       0.259116                          0                       0
# 4   14.0       5.185125                          0                       0
# 5   20.0       4.743102                          0                       0
# 6   12.0       5.128429                          0                       0
#
#             ...            neighborhood_Pointe-Claire  \
# 0           ...                                     0
# 1           ...                                     0
# 4           ...                                     0
# 5           ...                                     0
# 6           ...                                     0
#
#    neighborhood_Rivière-des-Prairies-Pointe-aux-Trembles  \
# 0                                                  0
# 1                                                  0
# 4                                                  0
# 5                                                  0
# 6                                                  0
#
#    neighborhood_Rosemont-La Petite-Patrie  neighborhood_Saint-Laurent  \
# 0                                       1                           0
# 1                                       0                           0
# 4                                       0                           0
# 5                                       1                           0
# 6                                       1                           0
#
#    neighborhood_Saint-Léonard  neighborhood_Sainte-Anne-de-Bellevue  \
# 0                           0                                     0
# 1                           0                                     0
# 4                           0                                     0
# 5                           0                                     0
# 6                           0                                     0
#
#    neighborhood_Verdun  neighborhood_Ville-Marie  \
# 0                    0                         0
# 1                    0                         1
# 4                    1                         0
# 5                    0                         0
# 6                    0                         0
#
#    neighborhood_Villeray-Saint-Michel-Parc-Extension  neighborhood_Westmount
# 0                                                  0                       0
# 1                                                  0                       0
# 4                                                  0                       0
# 5                                                  0                       0
# 6                                                  0                       0
#
# [5 rows x 43 columns]

# %% [markdown]
# # 5. Model Building

# %% [markdown]
# We will now split our data into a train and test set and more closely look at the correlations

# %%
from sklearn.cross_validation import train_test_split
train, test = train_test_split(df_ohe, train_size = 0.8)

# %% [markdown]
# Let us take a look at the correlation to see if there is anything interesting

# %%
#correlation matrix
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-183-57f8a3fe5c57> in <module>()
#       2 corrmat = train.corr()
#       3 f, ax = plt.subplots(figsize=(12, 9))
# ----> 4 sns.heatmap(corrmat, vmax=.8, square=True);
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/seaborn/matrix.pyc in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, ax, xticklabels, yticklabels, mask, **kwargs)
#     494     if square:
#     495         ax.set_aspect("equal")
# --> 496     plotter.plot(ax, cbar_ax, kwargs)
#     497     return ax
#     498
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/seaborn/matrix.pyc in plot(self, ax, cax, kws)
#     265         # Add row and column labels
#     266         ax.set(xticks=self.xticks, yticks=self.yticks)
# --> 267         xtl = ax.set_xticklabels(self.xticklabels)
#     268         ytl = ax.set_yticklabels(self.yticklabels, rotation="vertical")
#     269
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_xticklabels(self, labels, fontdict, minor, **kwargs)
#    3037             kwargs.update(fontdict)
#    3038         ret = self.xaxis.set_ticklabels(labels,
# -> 3039                                         minor=minor, **kwargs)
#    3040         self.stale = True
#    3041         return ret
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in set_ticklabels(self, ticklabels, *args, **kwargs)
#    1601         for tick_label, tick in zip(ticklabels, ticks):
#    1602             # deal with label1
# -> 1603             tick.label1.set_text(tick_label)
#    1604             tick.label1.update(kwargs)
#    1605             # deal with label2
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 23: ordinal not in range(128)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2198                     orientation=orientation,
#    2199                     dryrun=True,
# -> 2200                     **kwargs)
#    2201                 renderer = self.figure._cachedRenderer
#    2202                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#    1059                 continue
#    1060             tick.update_position(loc)
# -> 1061             tick.set_label1(label)
#    1062             tick.set_label2(label)
#    1063             ticks_to_draw.append(tick)
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in set_label1(self, s)
#     275         ACCEPTS: str
#     276         """
# --> 277         self.label1.set_text(s)
#     278         self.stale = True
#     279
#
# /Users/Heinrick/anaconda/lib/python2.7/site-packages/matplotlib/text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 23: ordinal not in range(128)

# %% [markdown]
# The overall satisfaction is strongly correlated to the number of reviews, that is not a surprise since the places with 0 scores seem to systematically have only a few reviews, room_id and host_id are strongly correlated since rooms and hosts are systematically associated together.
#
# We will now compare the performance of several models

# %%
X_train = train.drop("overall_satisfaction", axis=1)
Y_train = train["overall_satisfaction"]
X_test  = test.drop("overall_satisfaction", axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((9868, 42), (9868,), (2468, 42))

# %%
dd
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12336 entries, 0 to 15870
# Data columns (total 43 columns):
# room_id                                                  12336 non-null int64
# host_id                                                  12336 non-null int64
# reviews                                                  12336 non-null int64
# overall_satisfaction                                     12336 non-null float64
# accommodates                                             12336 non-null int64
# bedrooms                                                 12336 non-null float64
# price                                                    12336 non-null float64
# downtown_dist                                            12336 non-null float64
# room_type_Entire home/apt                                12336 non-null uint8
# room_type_Private room                                   12336 non-null uint8
# room_type_Shared room                                    12336 non-null uint8
# neighborhood_Ahuntsic-Cartierville                       12336 non-null uint8
# neighborhood_Anjou                                       12336 non-null uint8
# neighborhood_Baie-d'Urfé                                 12336 non-null uint8
# neighborhood_Beaconsfield                                12336 non-null uint8
# neighborhood_Côte-Saint-Luc                              12336 non-null uint8
# neighborhood_Côte-des-Neiges-Notre-Dame-de-Grâce         12336 non-null uint8
# neighborhood_Dollard-des-Ormeaux                         12336 non-null uint8
# neighborhood_Dorval                                      12336 non-null uint8
# neighborhood_Hampstead                                   12336 non-null uint8
# neighborhood_Kirkland                                    12336 non-null uint8
# neighborhood_L'Île-Bizard-Sainte-Geneviève               12336 non-null uint8
# neighborhood_LaSalle                                     12336 non-null uint8
# neighborhood_Lachine                                     12336 non-null uint8
# neighborhood_Le Plateau-Mont-Royal                       12336 non-null uint8
# neighborhood_Le Sud-Ouest                                12336 non-null uint8
# neighborhood_Mercier-Hochelaga-Maisonneuve               12336 non-null uint8
# neighborhood_Mont-Royal                                  12336 non-null uint8
# neighborhood_Montréal-Est                                12336 non-null uint8
# neighborhood_Montréal-Nord                               12336 non-null uint8
# neighborhood_Montréal-Ouest                              12336 non-null uint8
# neighborhood_Outremont                                   12336 non-null uint8
# neighborhood_Pierrefonds-Roxboro                         12336 non-null uint8
# neighborhood_Pointe-Claire                               12336 non-null uint8
# neighborhood_Rivière-des-Prairies-Pointe-aux-Trembles    12336 non-null uint8
# neighborhood_Rosemont-La Petite-Patrie                   12336 non-null uint8
# neighborhood_Saint-Laurent                               12336 non-null uint8
# neighborhood_Saint-Léonard                               12336 non-null uint8
# neighborhood_Sainte-Anne-de-Bellevue                     12336 non-null uint8
# neighborhood_Verdun                                      12336 non-null uint8
# neighborhood_Ville-Marie                                 12336 non-null uint8
# neighborhood_Villeray-Saint-Michel-Parc-Extension        12336 non-null uint8
# neighborhood_Westmount                                   12336 non-null uint8
# dtypes: float64(4), int64(4), uint8(35)
# memory usage: 1.6 MB

# %% [markdown]
# Expand: natural language processing
